# %% [markdown]
# ### Named Entity Recognition

# %% [markdown]
# sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."
# """
# Person Eg: Krish C Naik
# Place Or Location Eg: India
# Date Eg: September,24-09-1989
# Time  Eg: 4:30pm
# Money Eg: 1 million dollar
# Organization Eg: iNeuron Private Limited
# Percent Eg: 20%, twenty percent
# """

# %%
print("Hello world")
# Out:
# Hello world

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk

# %%
words = nltk.word_tokenize(sentence)

# %%
words
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  'Gustave',
#  'Eiffel',
#  ',',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures',
#  '.']

# %%
tag_elements = nltk.pos_tag(words)

# %%
nltk.ne_chunk(tag_elements).draw()

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk import word_tokenize, pos_tag, ne_chunk

text = "Barack Obama was born in Hawaii and worked for the United Nations."

# Tokenize
tokens = word_tokenize(text)

# POS tagging
pos_tags = pos_tag(tokens)
print(pos_tags)
# Out:
# [('Barack', 'NNP'), ('Obama', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('Hawaii', 'NNP'), ('and', 'CC'), ('worked', 'VBD'), ('for', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('Nations', 'NNPS'), ('.', '.')]

# %%
ner_tree = ne_chunk(pos_tags)
print(ner_tree)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP)
#   and/CC
#   worked/VBD
#   for/IN
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNPS)
#   ./.)

# %%
from nltk.tree import Tree

def extract_entities(tree):
    entities = []
    for subtree in tree:
        if type(subtree) == Tree:
            entity_name = " ".join([token for token, pos in subtree.leaves()])
            entity_type = subtree.label()
            entities.append((entity_name, entity_type))
    return entities

entities = extract_entities(ner_tree)
print(entities)
# Out:
# [('Barack', 'PERSON'), ('Obama', 'PERSON'), ('Hawaii', 'GPE'), ('United Nations', 'ORGANIZATION')]
