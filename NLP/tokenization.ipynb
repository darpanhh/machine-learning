# %%
corpus = '''
Hello Welcome,to Darpan Giri's NLP tutorials.
Please do see the whole code! to become expert in NLP.
'''

# %%
print(corpus)
# Out:
# Hello Welcome,to Darpan Giri's NLP tutorials.
# Please do see the whole code! to become expert in NLP.

# %% [markdown]
# ##  Tokenization
# ## Sentence-->paragraphs

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ["\nHello Welcome,to Darpan Giri's NLP tutorials.",
#  'Please do see the whole code!',
#  'to become expert in NLP.']

# %%
documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ["\nHello Welcome,to Darpan Giri's NLP tutorials.",
#  'Please do see the whole code!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Darpan Giri's NLP tutorials.
# Please do see the whole code!
# to become expert in NLP.

# %% [markdown]
# ## Tokenization
# ## Paragraph-->words
# ## sentence--->words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Darpan',
#  'Giri',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'see',
#  'the',
#  'whole',
#  'code',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Darpan', 'Giri', "'s", 'NLP', 'tutorials', '.']
# ['Please', 'do', 'see', 'the', 'whole', 'code', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Darpan',
#  'Giri',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'see',
#  'the',
#  'whole',
#  'code',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Darpan',
#  'Giri',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'do',
#  'see',
#  'the',
#  'whole',
#  'code',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
